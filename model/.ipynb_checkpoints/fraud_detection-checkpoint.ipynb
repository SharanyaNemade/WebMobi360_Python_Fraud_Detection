# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")
sns.set(style="whitegrid")

# %%
df=pd.read_csv("Enhanced_Fraud_Detection_Dataset.csv")

# %%
df.columns
# Out:
# Index(['TransactionID', 'Timestamp', 'Amount', 'OldBalanceOrigin',
#        'NewBalanceOrigin', 'OldBalanceDestination', 'NewBalanceDestination',
#        'BalanceDeltaOrigin', 'BalanceDeltaDestination', 'TransactionType',
#        'SenderID', 'ReceiverID', 'SenderLocation', 'SenderCountry',
#        'ReceiverLocation', 'ReceiverCountry', 'LocationMismatch',
#        'PreviousLinkWithReceiver', 'LinkHistoryCount', 'SenderPastFraudCount',
#        'ReceiverPastFraudCount', 'SenderAvgTransactionAmount',
#        'ReceiverAvgTransactionAmount', 'AmountDeviationFromSenderAvg',
#        'TransactionVelocity24h', 'AmountAnomalyFlag', 'BehaviorAnomalyFlag',
#        'FraudRiskScore', 'IsFraud'],
#       dtype='object')

# %%
df['SenderLocation'].unique()
# Out:
# array(['Bangalore', 'Kolkata', 'Lucknow', 'Hyderabad', 'Jaipur', 'Delhi',
#        'Chennai', 'Pune', 'Ahmedabad', 'Mumbai'], dtype=object)

# %%
# Set a small tolerance for float comparison
tol = 0.05  # e.g., 5 paisa

# Vectorized calculation of IsSuccessful
df["IsSuccessful"] = (
    (abs(df["NewBalanceOrigin"] - (df["OldBalanceOrigin"] - df["Amount"])) <= tol) &
    (abs(df["NewBalanceDestination"] - (df["OldBalanceDestination"] + df["Amount"])) <= tol)
).astype(int)

# %%
df["OriginMismatch"] = (df["OldBalanceOrigin"] - df["Amount"] != df["NewBalanceOrigin"]).astype(int)

df["DestMismatch"] = (df["OldBalanceDestination"] + df["Amount"] != df["NewBalanceDestination"]).astype(int)

# %%
import pandas as pd

# Function to convert hour → period
def time_to_period(hour):
    if 0 <= hour <= 5:
        return "Midnight"
    elif 6 <= hour <= 11:
        return "Morning"
    elif 12 <= hour <= 15:
        return "Afternoon"
    elif 16 <= hour <= 19:
        return "Evening"
    else:
        return "Night"

# Convert timestamp column
df["Timestamp"] = pd.to_datetime(df["Timestamp"])  # your column name
df["Hour"] = df["Timestamp"].dt.hour
df["TimePeriod"] = df["Hour"].apply(time_to_period)

# %%
df.columns
# Out:
# Index(['TransactionID', 'Timestamp', 'Amount', 'OldBalanceOrigin',
#        'NewBalanceOrigin', 'OldBalanceDestination', 'NewBalanceDestination',
#        'BalanceDeltaOrigin', 'BalanceDeltaDestination', 'TransactionType',
#        'SenderID', 'ReceiverID', 'SenderLocation', 'SenderCountry',
#        'ReceiverLocation', 'ReceiverCountry', 'LocationMismatch',
#        'PreviousLinkWithReceiver', 'LinkHistoryCount', 'SenderPastFraudCount',
#        'ReceiverPastFraudCount', 'SenderAvgTransactionAmount',
#        'ReceiverAvgTransactionAmount', 'AmountDeviationFromSenderAvg',
#        'TransactionVelocity24h', 'AmountAnomalyFlag', 'BehaviorAnomalyFlag',
#        'FraudRiskScore', 'IsFraud', 'IsSuccessful', 'OriginMismatch',
#        'DestMismatch', 'Hour', 'TimePeriod'],
#       dtype='object')

# %%
"""#Boxplots
plt.figure(figsize=(15, 8))
for i, col in enumerate([ 'IsSuccessful', 'OriginMismatch',
       'DestMismatch', 'Hour', 'TimePeriod' ]):
    plt.subplot(2,5 , i+1)
    sns.boxplot(df[col])
    plt.title(f'Boxplot of {col}')
plt.tight_layout()
plt.show()"""
# Out:
# "#Boxplots\nplt.figure(figsize=(15, 8))\nfor i, col in enumerate([ 'IsSuccessful', 'OriginMismatch',\n       'DestMismatch', 'Hour', 'TimePeriod' ]):\n    plt.subplot(2,5 , i+1)\n    sns.boxplot(df[col])\n    plt.title(f'Boxplot of {col}')\nplt.tight_layout()\nplt.show()"

# %%
"""#Boxplots
plt.figure(figsize=(15, 8))
for i, col in enumerate(['SenderAvgTransactionAmount',
       'ReceiverAvgTransactionAmount', 'AmountDeviationFromSenderAvg',
       'TransactionVelocity24h', 'AmountAnomalyFlag', 'BehaviorAnomalyFlag',
       'FraudRiskScore', 'IsFraud' ]):
    plt.subplot(2,4 , i+1)
    sns.boxplot(df[col])
    plt.title(f'Boxplot of {col}')
plt.tight_layout()
plt.show()"""
# Out:
# "#Boxplots\nplt.figure(figsize=(15, 8))\nfor i, col in enumerate(['SenderAvgTransactionAmount',\n       'ReceiverAvgTransactionAmount', 'AmountDeviationFromSenderAvg',\n       'TransactionVelocity24h', 'AmountAnomalyFlag', 'BehaviorAnomalyFlag',\n       'FraudRiskScore', 'IsFraud' ]):\n    plt.subplot(2,4 , i+1)\n    sns.boxplot(df[col])\n    plt.title(f'Boxplot of {col}')\nplt.tight_layout()\nplt.show()"

# %%
"""
#Boxplots
plt.figure(figsize=(15, 8))
for i, col in enumerate(['SenderCountry',
       'ReceiverLocation', 'ReceiverCountry', 'LocationMismatch',
       'PreviousLinkWithReceiver', 'LinkHistoryCount', 'SenderPastFraudCount',
       'ReceiverPastFraudCount', ]):
    plt.subplot(2,5 , i+1)
    sns.boxplot(df[col])
    plt.title(f'Boxplot of {col}')
plt.tight_layout()
plt.show()"""
# Out:
# "\n#Boxplots\nplt.figure(figsize=(15, 8))\nfor i, col in enumerate(['SenderCountry',\n       'ReceiverLocation', 'ReceiverCountry', 'LocationMismatch',\n       'PreviousLinkWithReceiver', 'LinkHistoryCount', 'SenderPastFraudCount',\n       'ReceiverPastFraudCount', ]):\n    plt.subplot(2,5 , i+1)\n    sns.boxplot(df[col])\n    plt.title(f'Boxplot of {col}')\nplt.tight_layout()\nplt.show()"

# %%
"""#Boxplots
plt.figure(figsize=(15, 8))
for i, col in enumerate([ 'Amount', 'OldBalanceOrigin',
       'NewBalanceOrigin', 'OldBalanceDestination', 'NewBalanceDestination',
        'TransactionType',
        'SenderLocation', ]):
    plt.subplot(2,5 , i+1)
    sns.boxplot(df[col])
    plt.title(f'Boxplot of {col}')
plt.tight_layout()
plt.show()"""
# Out:
# "#Boxplots\nplt.figure(figsize=(15, 8))\nfor i, col in enumerate([ 'Amount', 'OldBalanceOrigin',\n       'NewBalanceOrigin', 'OldBalanceDestination', 'NewBalanceDestination',\n        'TransactionType',\n        'SenderLocation', ]):\n    plt.subplot(2,5 , i+1)\n    sns.boxplot(df[col])\n    plt.title(f'Boxplot of {col}')\nplt.tight_layout()\nplt.show()"

# %%
df.columns
# Out:
# Index(['TransactionID', 'Timestamp', 'Amount', 'OldBalanceOrigin',
#        'NewBalanceOrigin', 'OldBalanceDestination', 'NewBalanceDestination',
#        'BalanceDeltaOrigin', 'BalanceDeltaDestination', 'TransactionType',
#        'SenderID', 'ReceiverID', 'SenderLocation', 'SenderCountry',
#        'ReceiverLocation', 'ReceiverCountry', 'LocationMismatch',
#        'PreviousLinkWithReceiver', 'LinkHistoryCount', 'SenderPastFraudCount',
#        'ReceiverPastFraudCount', 'SenderAvgTransactionAmount',
#        'ReceiverAvgTransactionAmount', 'AmountDeviationFromSenderAvg',
#        'TransactionVelocity24h', 'AmountAnomalyFlag', 'BehaviorAnomalyFlag',
#        'FraudRiskScore', 'IsFraud', 'IsSuccessful', 'OriginMismatch',
#        'DestMismatch', 'Hour', 'TimePeriod'],
#       dtype='object')

# %%
# Select only numeric cols
numeric_data = df.select_dtypes(include=[np.number])
corr_matrix = numeric_data.corr()

plt.figure(figsize=(20, 15))
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', fmt='.2f')
plt.title("Correlation Matrix")
plt.show()

# %%
from xgboost import XGBClassifier
from sklearn.metrics import classification_report
from sklearn.model_selection import train_test_split
from imblearn.over_sampling import SMOTE

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.compose import ColumnTransformer
import numpy as np

# %%
df.columns
# Out:
# Index(['TransactionID', 'Timestamp', 'Amount', 'OldBalanceOrigin',
#        'NewBalanceOrigin', 'OldBalanceDestination', 'NewBalanceDestination',
#        'BalanceDeltaOrigin', 'BalanceDeltaDestination', 'TransactionType',
#        'SenderID', 'ReceiverID', 'SenderLocation', 'SenderCountry',
#        'ReceiverLocation', 'ReceiverCountry', 'LocationMismatch',
#        'PreviousLinkWithReceiver', 'LinkHistoryCount', 'SenderPastFraudCount',
#        'ReceiverPastFraudCount', 'SenderAvgTransactionAmount',
#        'ReceiverAvgTransactionAmount', 'AmountDeviationFromSenderAvg',
#        'TransactionVelocity24h', 'AmountAnomalyFlag', 'BehaviorAnomalyFlag',
#        'FraudRiskScore', 'IsFraud', 'IsSuccessful', 'OriginMismatch',
#        'DestMismatch', 'Hour', 'TimePeriod'],
#       dtype='object')

# %%
df.head()
# Out:
#   TransactionID           Timestamp   Amount  OldBalanceOrigin  \
# 0    TXN2001066 2025-11-16 22:13:00   118.74          18114.22
# 1    TXN1000121 2025-12-06 19:14:00  7826.51          13930.24
# 2    TXN2001836 2025-12-04 23:22:00   691.18           3411.06
# 3    TXN1000852 2025-11-25 18:46:00  7958.68          38632.92
# 4    TXN1000439 2025-11-26 19:48:00  6866.85           9123.43
#
#    NewBalanceOrigin  OldBalanceDestination  NewBalanceDestination  \
# 0          17995.48               17660.35               17779.08
# 1           6103.73               14560.20               22386.71
# 2           2719.89               15474.23               16165.41
# 3          30674.24                 815.99                8774.67
# 4           2256.58               12164.22               19031.07
#
#    BalanceDeltaOrigin  BalanceDeltaDestination TransactionType  ...  \
# 0              118.74                   118.74        TRANSFER  ...
# ...

# %%
df = df.drop(['TransactionID', 'Timestamp','SenderID', 'ReceiverID','SenderCountry',
       'SenderPastFraudCount', 'ReceiverPastFraudCount', 'ReceiverAvgTransactionAmount',  'ReceiverCountry', 'OriginMismatch', 'DestMismatch','Hour'], axis=1)

# %%
"""

numeric_cols = ['Amount', 'OldBalanceOrigin', 'NewBalanceOrigin',
       'OldBalanceDestination', 'NewBalanceDestination',
       'LocationMismatch', 'PreviousLinkWithReceiver', 'LinkHistoryCount',
       'SenderAvgTransactionAmount',
       'AmountDeviationFromSenderAvg', 'TransactionVelocity24h',
       'AmountAnomalyFlag', 'BehaviorAnomalyFlag',
       'IsSuccessful', 'OriginMismatch', 'DestMismatch' ]
categorical_cols = [ 'TransactionType', 'SenderLocation','ReceiverLocation','TimePeriod']


preprocess = ColumnTransformer([
    ("num", StandardScaler(), numeric_cols),
    ("cat", OneHotEncoder(handle_unknown="ignore"), categorical_cols)
])
X_processed = preprocess.fit_transform(X)"""
# Out:
# 'X = df.drop(columns=["IsFraud","FraudRiskScore"], axis=1)\ny = df["IsFraud"]\n\nnumeric_cols = [\'Amount\', \'OldBalanceOrigin\', \'NewBalanceOrigin\',\n       \'OldBalanceDestination\', \'NewBalanceDestination\',\n       \'LocationMismatch\', \'PreviousLinkWithReceiver\', \'LinkHistoryCount\',\n       \'SenderAvgTransactionAmount\',\n       \'AmountDeviationFromSenderAvg\', \'TransactionVelocity24h\',\n       \'AmountAnomalyFlag\', \'BehaviorAnomalyFlag\',\n       \'IsSuccessful\', \'OriginMismatch\', \'DestMismatch\' ]\ncategorical_cols = [ \'TransactionType\', \'SenderLocation\',\'ReceiverLocation\',\'TimePeriod\']\n\n\npreprocess = ColumnTransformer([\n    ("num", StandardScaler(), numeric_cols),\n    ("cat", OneHotEncoder(handle_unknown="ignore"), categorical_cols)\n])\nX_processed = preprocess.fit_transform(X)'

# %%
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.compose import ColumnTransformer
X = df.drop(columns=["IsFraud","FraudRiskScore"], axis=1)
y = df["IsFraud"]
numeric_cols = ['Amount', 'OldBalanceOrigin', 'NewBalanceOrigin',
       'OldBalanceDestination', 'NewBalanceDestination',
       'LocationMismatch', 'PreviousLinkWithReceiver', 'LinkHistoryCount',
       'SenderAvgTransactionAmount',
       'AmountDeviationFromSenderAvg', 'TransactionVelocity24h',
       'AmountAnomalyFlag', 'BehaviorAnomalyFlag',
       'IsSuccessful' ]

categorical_cols = ['TransactionType', 'SenderLocation','ReceiverLocation','TimePeriod']

preprocess = ColumnTransformer([
    ("num", StandardScaler(), numeric_cols),
    ("cat", OneHotEncoder(handle_unknown="ignore"), categorical_cols)
])

# Fit on training data
X_processed = preprocess.fit_transform(X)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[21], line 20
#      14 preprocess = ColumnTransformer([
#      15     ("num", StandardScaler(), numeric_cols),
#      16     ("cat", OneHotEncoder(handle_unknown="ignore"), categorical_cols)
#      17 ])
#      19 # Fit on training data
# ---> 20 X_processed = preprocess.fit_transform(X)
#
# NameError: name 'X' is not defined

# %%
X_train, X_test, y_train, y_test = train_test_split(X_processed, y, test_size=0.2)

model = XGBClassifier(
    n_estimators=400,
    learning_rate=0.05,
    max_depth=6,
    subsample=0.8,
    colsample_bytree=0.8,
    eval_metric="logloss"
)

model.fit(X_train, y_train)
preds = model.predict(X_test)

print(classification_report(y_test, preds))

# %%
from sklearn.metrics import classification_report, confusion_matrix

y_pred = (model.predict(X_test) > 0.5).astype(int)

print(confusion_matrix(y_test, y_pred))

# %%
import joblib
import pickle

# %%
joblib.dump(model, "fraud_detect_model.pkl")
print("✅ Model saved as fraud_detect_model.pkl")

# %%
model = joblib.load("fraud_detect_model.pkl")

# %%
# Load preprocessing pipeline
import pickle
pickle.dump(preprocess, open("preprocess.pkl", "wb"))
pickle.dump(model, open("fraud_detect_model.pkl", "wb"))

# %%
X.columns

# %%
X.head()

# %%
# New transaction sample (values must match feature order!)
# step, type, amount, oldbalanceOrg, newbalanceOrig, oldbalanceDest, newbalanceDest
new_transaction = pd.DataFrame([{
    "Amount": 1864.28,
    "OldBalanceOrigin": 21249,
    "NewBalanceOrigin": 19384.72,
    "OldBalanceDestination": 0,
    "NewBalanceDestination": 0,

    # Engineered features (auto or dummy values)
    "BalanceDeltaOrigin": 19384.72 - 21249,            # OR  -1864.28
    "BalanceDeltaDestination": 0 - 0,                  # 0

    "TransactionType": "PAYMENT",

    # IDs (you may generate your own IDs)
    "SenderID": "User123",
    "ReceiverID": "User456",

    # Locations
    "SenderLocation": "Unknown",
    "SenderCountry": "Unknown",
    "ReceiverLocation": "Unknown",
    "ReceiverCountry": "Unknown",

    # Relationship history
    "LocationMismatch": 0,
    "PreviousLinkWithReceiver": 0,
    "LinkHistoryCount": 0,

    # Past fraud counts
    "SenderPastFraudCount": 0,
    "ReceiverPastFraudCount": 0,

    # Aggregate averages
    "SenderAvgTransactionAmount": 2000,
    "ReceiverAvgTransactionAmount": 0,

    # Amount deviation
    "AmountDeviationFromSenderAvg": abs(1864.28 - 2000),

    # Behavior / velocity
    "TransactionVelocity24h": 1,
    "AmountAnomalyFlag": 0,
    "BehaviorAnomalyFlag": 0,
    "IsSuccessful":0,

    # Geo mismatch
    "OriginMismatch": 0,
    "DestMismatch": 0,

    # Time features
    "Hour": 22,
    "TimePeriod": "Night"
}])

# Apply preprocessing
new_processed = preprocess.transform(new_transaction)

# Predict fraud probability
fraud_prob = float(model.predict_proba(new_processed)[0][1])  
prediction = 'Fraud' if fraud_prob >= 0.5 else 'Not Fraud'


print("Fraud Probability:", fraud_prob)
print("Prediction:", "Fraud" if prediction == 1 else "Not Fraud")

# %%
#def fraud_prediction():
    # Set a small tolerance for float comparison

# %%
"""X1 = df.drop(columns=["FraudRiskScore"], axis=1)
y1 = df["FraudRiskScore"]

numeric_cols = [
    'Amount', 'OldBalanceOrigin', 'NewBalanceOrigin',
    'OldBalanceDestination', 'NewBalanceDestination',
    'LocationMismatch', 'PreviousLinkWithReceiver', 'LinkHistoryCount',
    'SenderAvgTransactionAmount', 'ReceiverAvgTransactionAmount',
    'AmountDeviationFromSenderAvg', 'TransactionVelocity24h',
    'AmountAnomalyFlag', 'BehaviorAnomalyFlag',
    'IsSuccessful', 'OriginMismatch', 'DestMismatch'
]

categorical_cols = [
    'TransactionType', 'SenderLocation', 'ReceiverLocation', 'TimePeriod'
]

preprocess = ColumnTransformer([
    ("num", StandardScaler(), numeric_cols),
    ("cat", OneHotEncoder(handle_unknown="ignore"), categorical_cols)
])

X_processed = preprocess.fit_transform(X1)

X_train, X_test, y_train, y_test = train_test_split(
    X_processed, y1, test_size=0.2, random_state=42
)
from xgboost import XGBRegressor

model1 = XGBRegressor(
    n_estimators=400,
    learning_rate=0.05,
    max_depth=6,
    subsample=0.8,
    colsample_bytree=0.8,
)
model1.fit(X_train, y_train)

preds = model1.predict(X_test)"""

# %%
from sklearn.metrics import r2_score, mean_absolute_error, mean_squared_error
import numpy as np

# R² Score
r2 = r2_score(y_test, preds)

# MAE
mae = mean_absolute_error(y_test, preds)

# RMSE
rmse = np.sqrt(mean_squared_error(y_test, preds))

print("R² Score:", r2)
print("MAE:", mae)
print("RMSE:", rmse)

# %%
import os
import pandas as pd
from datetime import datetime, timedelta
import joblib
import pickle

# %%
TRANSACTION_HISTORY_FILE = "data/transaction_history.csv"

def load_transaction_history():
    if os.path.exists(TRANSACTION_HISTORY_FILE):
        return pd.read_csv(
            TRANSACTION_HISTORY_FILE,
            parse_dates=["Timestamp"]
        )
    else:
        return pd.DataFrame(columns=[
            "TransactionID",
            "SenderID",
            "ReceiverID",
            "Amount",
            "Timestamp",
            "SenderLocation",
            "ReceiverLocation"
        ])

# %%
def predict_transaction(
    transaction_id,
    transaction_type,
    amount,
    old_org,
    new_org,
    old_dest,
    new_dest,
    sender_id,
    receiver_id,
    transaction_time,
    sender_location,
    receiver_location
):
    """
    Predict fraud risk score and fraud label from manual user input
    """

    # ---------------------------
    # Load transaction history
    # ---------------------------
    history_df = load_transaction_history()

    # ---------------------------
   # ---------------------------
    # Convert transaction_time
    # ---------------------------
    if isinstance(transaction_time, str):
        dt = datetime.strptime(transaction_time, "%d-%m-%Y %H:%M")
    else:
        dt = transaction_time

    # ---------------------------
    # Sender-specific history
    # ---------------------------
    sender_history = history_df[
        history_df["SenderID"] == sender_id
    ]

    # ---------------------------
    # Previous sender-receiver link
    # ---------------------------
    previous_links = sender_history[
        sender_history["ReceiverID"] == receiver_id
    ]

    previous_link = 1 if not previous_links.empty else 0
    link_count = len(previous_links)

    # ---------------------------
    # Sender average transaction
    # ---------------------------
    if not sender_history.empty:
        sender_avg_amount = sender_history["Amount"].mean()
    else:
        sender_avg_amount = amount

    amount_deviation = abs(amount - sender_avg_amount)

    # ---------------------------
    # Velocity (last 24 hours)
    # ---------------------------
    recent_txns = sender_history[
        sender_history["Timestamp"] >= (dt - timedelta(hours=24))
    ]

    transaction_velocity_24h = len(recent_txns)

    # ---------------------------
    # Time features
    # ---------------------------
    hour = dt.hour

    if 0 <= hour < 6:
        time_period = "Night"
    elif 6 <= hour < 12:
        time_period = "Morning"
    elif 12 <= hour < 18:
        time_period = "Afternoon"
    else:
        time_period = "Evening"

    # ---------------------------
    # Balance features
    # ---------------------------
    balance_delta_origin = abs(old_org - new_org)
    balance_delta_dest = abs(new_dest - old_dest)

    # ---------------------------
    # Transaction success
    # ---------------------------
    is_successful = int(
        abs(new_org - (old_org - amount)) < 0.05 and
        abs(new_dest - (old_dest + amount)) < 0.05
    )

    # ---------------------------
    # Mismatch & anomaly rules
    # ---------------------------
    location_mismatch = int(sender_location != receiver_location)

    # downgrade effect if same country
    if sender_location in INDIA_CITIES and receiver_location in INDIA_CITIES:
        location_mismatch = 0
    origin_mismatch = int(round(new_org, 2) != round(old_org - amount, 2))
    dest_mismatch   = int(round(new_dest, 2) != round(old_dest + amount, 2))


    amount_anomaly_flag = int(
        not sender_history.empty and amount > 3 * sender_avg_amount
    )

    

    # Ensure proper datetime
    history_df["Timestamp"] = pd.to_datetime(history_df["Timestamp"], errors="coerce")
    history_df = history_df.dropna(subset=["Timestamp"])

    # Remove duplicates
    history_df = history_df.drop_duplicates(
        subset=["TransactionID"],
        keep="first"
    )

    # Clean sender id
    history_df["SenderID"] = history_df["SenderID"].astype(str).str.strip()
    sender_id = sender_id.strip()

    sender_history = history_df[history_df["SenderID"] == sender_id]

    cutoff_time = dt - timedelta(hours=24)

    recent_txns = sender_history[
        (sender_history["Timestamp"] >= cutoff_time) &
        (sender_history["Timestamp"] <= dt) &
        (sender_history["TransactionID"] != transaction_id)
    ]

    transaction_velocity_24h = recent_txns.shape[0]

    behavior_score = 0

    if location_mismatch:
        behavior_score += 1
    if previous_link == 0:
        behavior_score += 1
    if transaction_velocity_24h > 5:
        behavior_score += 1
    if amount_deviation > sender_avg_amount:
        behavior_score += 1

    behavior_anomaly_flag = int(behavior_score >= 2)

    # ---------------------------
    # Build model input
    # ---------------------------
    data = {
        "Amount": amount,
        "OldBalanceOrigin": old_org,
        "NewBalanceOrigin": new_org,
        "OldBalanceDestination": old_dest,
        "NewBalanceDestination": new_dest,
        "BalanceDeltaOrigin": balance_delta_origin,
        "BalanceDeltaDestination": balance_delta_dest,
        "TransactionType": transaction_type,
        "SenderLocation": sender_location,
        "ReceiverLocation": receiver_location,
        "LocationMismatch": location_mismatch,
        "PreviousLinkWithReceiver": previous_link,
        "LinkHistoryCount": link_count,
        "SenderAvgTransactionAmount": sender_avg_amount,
        "AmountDeviationFromSenderAvg": amount_deviation,
        "TransactionVelocity24h": transaction_velocity_24h,
        "AmountAnomalyFlag": amount_anomaly_flag,
        "BehaviorAnomalyFlag": behavior_anomaly_flag,
        "IsSuccessful": is_successful,
        "Hour": hour,
        "TimePeriod": time_period
    }

    df_new = pd.DataFrame([data])

    # ---------------------------
    # Predict
    # ---------------------------
    X_new = preprocess.transform(df_new)
    if hasattr(model, "predict_proba"):
        fraud_risk_score = model.predict_proba(X_new)[0][1]
    else:
        fraud_risk_score = model.predict(X_new)[0]

    fraud_label = "Fraud" if fraud_risk_score >= 0.5 else "Not Fraud"

    # ---------------------------
    # Save transaction to history
    # ---------------------------
    new_record = {
        "TransactionID": transaction_id,
        "SenderID": sender_id,
        "ReceiverID": receiver_id,
        "Amount": amount,
        "Timestamp": dt,
        "SenderLocation": sender_location,
        "ReceiverLocation": receiver_location
    }

    history_df = pd.concat(
        [history_df, pd.DataFrame([new_record])],
        ignore_index=True
    )

    history_df.to_csv(TRANSACTION_HISTORY_FILE, index=False)

    # ---------------------------
    # Return result
    # ---------------------------
    fraud_reasons = []

    if amount_anomaly_flag == 1:
        fraud_reasons.append("Unusually high transaction amount compared to sender history")

    if location_mismatch == 1:
        fraud_reasons.append("Sender and receiver locations do not match")

    if transaction_velocity_24h > 5:
        fraud_reasons.append("Too many transactions in the last 24 hours")

    if previous_link == 0:
        fraud_reasons.append("No previous transaction history with this receiver")

    if origin_mismatch == 1 or dest_mismatch == 1:
        fraud_reasons.append("Balance mismatch detected after transaction")

    if not fraud_reasons:
        fraud_reasons.append("No strong fraud indicators detected")
    print(sender_history[["TransactionID","SenderID", "ReceiverID","Timestamp"]].sort_values("Timestamp"))

    # ---------------------------
    # Return result
    # ---------------------------
    return {
        "TransactionID": transaction_id,
        "FraudRiskScore": round(float(fraud_risk_score), 3),
        "Prediction": fraud_label,
        "IsSuccessful": is_successful,
        "TimePeriod": time_period,
        "FraudReasons": fraud_reasons,
        "TransactionType": transaction_type,
        "SenderLocation": sender_location,
        "ReceiverLocation": receiver_location,
        "LocationMismatch": location_mismatch,
        "PreviousLinkWithReceiver": previous_link,
        "LinkHistoryCount": link_count,
        "SenderAvgTransactionAmount": sender_avg_amount,
        "AmountDeviationFromSenderAvg": amount_deviation,
        "TransactionVelocity24h": transaction_velocity_24h,
        "AmountAnomalyFlag": amount_anomaly_flag,
        "BehaviorAnomalyFlag": behavior_anomaly_flag,
        "IsSuccessful": is_successful,
        "Hour": hour,
        "TimePeriod": time_period
        
    }

# %%
# Example transaction details
transaction_id = "TXN1000852"
transaction_type = "TRANSFER"
amount = 1396.27
old_org = 45894.52
new_org = 44498.25
old_dest = 7215.45
new_dest = 8611.72
sender_id = "CUST_SEND_23"
receiver_id = "CUST_RECV_56"
transaction_time = "01-12-2025 23:31"
sender_location = "Delhi"
receiver_location = "Chennai"

# Call the function
result = predict_transaction(
    transaction_id,
    transaction_type,
    amount,
    old_org,
    new_org,
    old_dest,
    new_dest,
    sender_id,
    receiver_id,
    transaction_time,
    sender_location,
    receiver_location
)

# Print the result
print("Prediction:", result)
